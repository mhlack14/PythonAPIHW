# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
cities = pd.read_csv("out_data/cities.csv")
cities
# Out:
#      City_ID           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          0   puerto ayora  -0.74  -90.35     72.00        84          92
# 1          1       bengkulu  -3.80  102.27     74.80        90          84
# 2          2       marsabit   2.33   37.99     72.88        51          99
# 3          3     kaitangata -46.28  169.85     44.01        81          91
# 4          4  leningradskiy  69.38  178.42     45.30        78           0
# ..       ...            ...    ...     ...       ...       ...         ...
# 552      552         bereda  43.27   -7.54     64.99        74          12
# 553      553      bundaberg -24.85  152.35     57.20        87           9
# 554      554     winnemucca  40.97 -117.74     78.80        16           1
# 555      555        awjilah  29.11   21.29     82.56        50           0
# 556      556       key west  24.56  -81.78     91.40        59          20
#
#      Wind Speed Country        Date
# ...

# %%
gmaps.configure(api_key=g_key)

g_key
# Out:
# 'AIzaSyD7MVJgDRmX5BHZi4T9e-auIzpiCUZC5fk'

# %%
citylocation = cities[["Lat", "Lng"]]
humidity = cities["Humidity"]
figure = gmaps.figure()
heat_layer = gmaps.heatmap_layer(citylocation, weights=humidity, dissipating=False, max_intensity=350, point_radius=7)

figure.add_layer(heat_layer)

print(figure)
print(heat_layer)
# Out:
# Figure(layout=FigureLayout(height='420px'))
# ...

# %%
#Create new DataFrame fitting weather criteria¶
#Narrow down the cities to fit weather conditions.
#Drop any rows will null values.

# %%
# Narrow down cities that fit criteria i.e. Max temp less than 80 but greater than 70 with wind speeds less than 10mph
#...and drop any results with null values. Display results

CriteriaCities = cities.loc[(cities["Max Temp"] < 80) & 
                                    (cities["Max Temp"] > 70) \
                                    & (cities["Wind Speed"]<10) \
                                    & (cities["Cloudiness"]==0)].dropna()
#check to make sure code works properly, visually. 50 columns is enough to see per the .head function. 
CriteriaCities.head(50)
# Out:
#      City_ID                     City    Lat    Lng  Max Temp  Humidity  \
# 29        29                   omboue  -1.57   9.26     73.26        87
# 68        68                   kaputa  -8.47  29.66     70.20        49
# 86        86                    igrim  63.19  64.42     71.89        70
# 90        90             ponta do sol  32.67 -17.10     73.99        72
# 121      121                    andra  62.51  65.89     74.28        67
# 162      162                kontagora  10.40   5.47     77.18        82
# 229      229                     lata  40.16  -8.33     78.01        67
# 275      275                     hami  42.80  93.45     79.38        21
# 388      388                   boueni -12.90  45.08     75.20        88
# 406      406             polunochnoye  60.87  60.42     71.20        75
# 409      409                caravelas -17.71 -39.25     76.41        61
# 416      416                    tanta  30.79  31.00     72.10        87
# ...

# %%
#Hotel Map¶
#store into variable named hotel_df.
#Add a "Hotel Name" column to the DataFrame.
#Set parameters to search for hotels with 5000 meters.
#Hit the Google Places API for each city's coordinates.
#Store the first Hotel result into the DataFrame.
#Plot markers on top of the heatmap.

# %%
#Store into variable named hotel_df
hotel_df = CriteriaCities[["City", "Country", "Lat", "Lng"]].copy()

hotel_df
# Out:
#                         City Country    Lat    Lng
# 29                    omboue      GA  -1.57   9.26
# 68                    kaputa      ZM  -8.47  29.66
# 86                     igrim      RU  63.19  64.42
# 90              ponta do sol      PT  32.67 -17.10
# 121                    andra      RU  62.51  65.89
# 162                kontagora      NG  10.40   5.47
# 229                     lata      PT  40.16  -8.33
# 275                     hami      CN  42.80  93.45
# 388                   boueni      YT -12.90  45.08
# 406             polunochnoye      RU  60.87  60.42
# 409                caravelas      BR -17.71 -39.25
# 416                    tanta      EG  30.79  31.00
# 424                   yarega      RU  63.44  53.58
# 458  saint-michel-des-saints      CA  46.68 -73.92
# 464                   inongo      CD  -1.95  18.27
# 487                 siavonga      ZM -16.54  28.71
# 533        belaya kholunitsa      RU  58.84  50.85

# %%
#Hotel Name
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                         City Country    Lat    Lng Hotel Name
# 29                    omboue      GA  -1.57   9.26
# 68                    kaputa      ZM  -8.47  29.66
# 86                     igrim      RU  63.19  64.42
# 90              ponta do sol      PT  32.67 -17.10
# 121                    andra      RU  62.51  65.89
# 162                kontagora      NG  10.40   5.47
# 229                     lata      PT  40.16  -8.33
# 275                     hami      CN  42.80  93.45
# 388                   boueni      YT -12.90  45.08
# 406             polunochnoye      RU  60.87  60.42
# 409                caravelas      BR -17.71 -39.25
# 416                    tanta      EG  30.79  31.00
# 424                   yarega      RU  63.44  53.58
# 458  saint-michel-des-saints      CA  46.68 -73.92
# 464                   inongo      CD  -1.95  18.27
# 487                 siavonga      ZM -16.54  28.71
# 533        belaya kholunitsa      RU  58.84  50.85

# %%
#Parameters to be set
parameters = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}
#check to see paramters code works
parameters
# Out:
# {'radius': 5000,
#  'types': 'lodging',
#  'key': 'AIzaSyD7MVJgDRmX5BHZi4T9e-auIzpiCUZC5fk'}

# %%
#Hit the Google Places API for each city's coordinates.
 
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    parameters["location"] = f"{lat},{lng}"
    #Reference the google data
    URL="https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    URLrequest = requests.get(URL, params=parameters)
    #Jsonify
    URLrequest=URLrequest.json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = URLrequest["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
hotel_df
# Out:
# Missing field/result... skipping.
#                         City Country    Lat    Lng  \
# 29                    omboue      GA  -1.57   9.26
# 68                    kaputa      ZM  -8.47  29.66
# 86                     igrim      RU  63.19  64.42
# 90              ponta do sol      PT  32.67 -17.10
# 121                    andra      RU  62.51  65.89
# 162                kontagora      NG  10.40   5.47
# 229                     lata      PT  40.16  -8.33
# 275                     hami      CN  42.80  93.45
# 388                   boueni      YT -12.90  45.08
# 406             polunochnoye      RU  60.87  60.42
# 409                caravelas      BR -17.71 -39.25
# 416                    tanta      EG  30.79  31.00
# 424                   yarega      RU  63.44  53.58
# 458  saint-michel-des-saints      CA  46.68 -73.92
# 464                   inongo      CD  -1.95  18.27
# 487                 siavonga      ZM -16.54  28.71
# 533        belaya kholunitsa      RU  58.84  50.85
#
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer on top of heat map
marker = gmaps.marker_layer(locations, info_box_content=hotel_info)
figure.add_layer(marker)

# Display figure
print(figure)
# Out:
# Figure(layout=FigureLayout(height='420px'))
